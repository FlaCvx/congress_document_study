# %%
import os
import numpy as np

# %%
input_file_path = './data/1789to1824_DebatesAndProceedings/text_volumes/Volume_3/page_10.txt'

with open(input_file_path, 'r') as input_file:
    my_text = input_file.read(-1)
    # my_text = re.split(r'\n{2,}', my_text)
    # my_text = [new_ele.replace("\t", " ") for new_ele in my_text]
    # my_text = re.split(r'\n{2,}', my_text)


    print(my_text)
    print(type(my_text))
# Out:
# LANGDON, be a committee to take into considera-
# tion the subject relative to Weights and Measures,
# and report their opinion thereon.
# Ordered, That Messrs. RutHerfurd, SHER-
# MAN, and BURR, be a committee to report a bill
# determining the time of choosing the Electors
# President and Vice President, and the day in which
# they shall give their votes, and prescribing the
# mode of transmitting the votes to the seat of Go-
# vernment.
# МONAOE
# compensation for the officers of the' Judicial
# Courts of the United States, and for jurors and
# witnesses
# Ordered, That Messrs. Kinc, FosTer, MonRor,
# STRONG, and Butler, be a committee to report a
# bill for establishing offices for the purpose of Grant-
# ing Lands within the territories of the United
# States
# be a committee to report a bill providing
# That Messrs. МоRRIS, CABOT, and
# Ordere, be a committee to report a bill con-1
# cerning Consuls and Vice Consuls
# Ordered, That Messrs. BurR, BuTleR, and Ro-
# ...
